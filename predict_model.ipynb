# %%
import joblib
import numpy as np

# %%
model = joblib.load("/content/model.pkl")

# %%
sample = np.array([[30, 3, 2]])  # adjust features

# %%
# Example prediction
sample = np.array([[30, 3, 2]])  # adjust features

# %%
prediction = model.predict(sample_df)
print("Prediction:", prediction)
# Out:
# Prediction: [3]
